# %% [markdown]
# <a href="https://colab.research.google.com/github/Thapanee05/workshop/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# Out:
# ...
#      |████████████████████████████████| 462 kB 4.3 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from IPython.display import Image

# %%
import pathlib
path = "drive/My Drive/Colab Notebooks/RICED" 
data_dir = pathlib.Path(path)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 400

# %%
Riceten = list(data_dir.glob('Riceten/*')) 
PIL.Image.open(str(Riceten[37]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x1706 at 0x7FB9ACE4EE50>

# %%
batch_size = 32
img_height = 243
img_width = 182

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
data_dir,
validation_split=0.2,
subset="training",
seed=123,
image_size=(img_height, img_width),
batch_size=batch_size)
# Out:
# Found 400 files belonging to 4 classes.
# Using 320 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
data_dir,
validation_split=0.2,
subset="validation",
seed=123,
image_size=(img_height, img_width),
batch_size=batch_size)
# Out:
# Found 400 files belonging to 4 classes.
# Using 80 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Ricefive', 'Riceml', 'Ricesix', 'Riceten']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
num_classes = 4
model = Sequential([
layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
layers.Conv2D(16, 3, padding='same', activation='relu'),
layers.MaxPooling2D(),
layers.Conv2D(32, 3, padding='same', activation='relu'),
layers.MaxPooling2D(),
layers.Conv2D(64, 3, padding='same', activation='relu'),
layers.MaxPooling2D(),
layers.Flatten(),
layers.Dense(128, activation='relu'),
layers.Dense(num_classes)])

# %%
model.compile(optimizer='adam',
loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_1 (Rescaling)     (None, 243, 182, 3)       0
#
#  conv2d (Conv2D)             (None, 243, 182, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 121, 91, 16)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 121, 91, 32)       4640
#
#  max_pooling2d_1 (MaxPooling  (None, 60, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 42240)             0
#
#  dense (Dense)               (None, 128)               5406848
#
#  dense_1 (Dense)             (None, 4)                 516
#
# ...
# Total params: 5,430,948
# Trainable params: 5,430,948
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(train_ds,
validation_data=val_ds,
epochs=epochs)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 40s 4s/step - loss: 1.9292 - accuracy: 0.2719 - val_loss: 1.3711 - val_accuracy: 0.2750
# Epoch 2/10
# 10/10 [==============================] - 14s 1s/step - loss: 1.2606 - accuracy: 0.4094 - val_loss: 1.1763 - val_accuracy: 0.4000
# Epoch 3/10
# 10/10 [==============================] - 14s 1s/step - loss: 0.9881 - accuracy: 0.5781 - val_loss: 0.8799 - val_accuracy: 0.8125
# Epoch 4/10
# 10/10 [==============================] - 14s 1s/step - loss: 0.7353 - accuracy: 0.7531 - val_loss: 0.9329 - val_accuracy: 0.6500
# Epoch 5/10
# 10/10 [==============================] - 14s 1s/step - loss: 0.7151 - accuracy: 0.7250 - val_loss: 0.7113 - val_accuracy: 0.7000
# Epoch 6/10
# 10/10 [==============================] - 13s 1s/step - loss: 0.5845 - accuracy: 0.7844 - val_loss: 0.5925 - val_accuracy: 0.8000
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(epochs)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
path = "/content/drive/My Drive/Colab Notebooks/Rice/Riceml/riceml48.jpg"
img = keras.preprocessing.image.load_img(
path, target_size=(img_height, img_width))
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
display(Image(filename=path))
print(
"This image most likely belongs to {} with a {:.2f} percent confidence."
.format(class_names[np.argmax(score)], 100 * np.max(score)))
# Out:
# This image most likely belongs to Riceml with a 99.91 percent confidence.

# %%
path = "/content/drive/My Drive/Colab Notebooks/RICED/Ricesix/ricerd43.jpg"
img = keras.preprocessing.image.load_img(
path, target_size=(img_height, img_width))
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
display(Image(filename=path))
print(
"This image most likely belongs to {} with a {:.2f} percent confidence."
.format(class_names[np.argmax(score)], 100 * np.max(score)))
# Out:
# This image most likely belongs to Ricesix with a 93.92 percent confidence.

# %%
path = "/content/drive/My Drive/Colab Notebooks/Rice/Riceten/riceten27.jpg"
img = keras.preprocessing.image.load_img(
path, target_size=(img_height, img_width))
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
display(Image(filename=path))
print(
"This image most likely belongs to {} with a {:.2f} percent confidence."
.format(class_names[np.argmax(score)], 100 * np.max(score)))
# Out:
# This image most likely belongs to Riceten with a 99.99 percent confidence.

# %%
path = "/content/drive/My Drive/Colab Notebooks/RICED/Ricefive/ricefive57.jpg"
img = keras.preprocessing.image.load_img(
path, target_size=(img_height, img_width))
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
display(Image(filename=path))
print(
"This image most likely belongs to {} with a {:.2f} percent confidence."
.format(class_names[np.argmax(score)], 100 * np.max(score)))
# Out:
# This image most likely belongs to Ricefive with a 94.69 percent confidence.
